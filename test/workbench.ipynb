# %%
reload("repl.jl");

# %%
xdump(sim)
# Out:
# Simulation
#   EVENTS: Int64 25
#   REPORTERS: Int64 50
#   ITERMAX: Int64 25
#   SQRTN: Float64 15
# .811388300841896
#   TIMESTEPS: Int64 250
#   SCALARS: Float64 0.2
#   SCALARMIN: Float64 0.0
#   SCALARMAX: Float64 1000.0
#   LIAR_THRESHOLD: Float64 0.7
#   VARIANCE_THRESHOLD: Float64 0.9
#   DISTORTER: Bool false
#   DISTORT: Float64 0.0
#   DISTORT_THRESHOLD: Float64 0.1
#   RESPONSES: FloatRange
# {Float64}
#     start: Float64 2.0
#     step: Float64 1.0
#     len: Float64 3.0
#     divisor: Float64 2.0
#   ALPHA: Float64 0.2
#   REP_BINS: Int64 10
#   REP_RAND: Bool true
#   REP_DIST: Pareto
#
#     α: Float64 3.0
#     β: Float64 1.0
#   BRIDGE: Bool false
#   MARKET_DIST: Pareto
#     α: Float64 3.0
#     β: Float64 1.0
#   PRICE_DIST: Uniform
#     a: Float64 0.0
#     b: Float64 1.0
#   OVERLAP_DIST: Exponential
#
#     β: Float64 1.0
#   RARE: Float64 1.0e-5
#   MONEYBIN: Float64 24.0
#   CORRUPTION: Float64 0.75
#   COLLUDE: Float64 0.3
#   INDISCRIMINATE: Bool true
#   VERBOSE: Bool false
#   CONSPIRACY: Bool true
#   ALLWRONG: Bool false
#   VIRIALMAX: Int64 8
#   LABELSORT: Bool true
#   SAVE_RAW_DATA: Bool false
#   MAX_COMPONENTS: Int64 2
#   PRESET: Bool false
#   PRESET_DATA: Dict{Symbol,Any}
#     slots: Array(Uint8,(16,))
# Uint8[0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00,0x00]
#     keys: Array(Symbol,(16,))
# [#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef,#undef]
#     vals: Array(Any,(16,))
#       1: #undef
#       2: #undef
#       3: #undef
#       4: #undef
#       5: #undef
#       ...
#       12: #undef
#       13: #undef
#       14: #undef
#       15: #undef
#       16: #undef
#     ndel: Int64 0
#     count: Int64 0
#     deleter: identity
#   ALGOS: Array(ASCIIString,(4,))
# ASCIIString["sztorc","big-five","absolute","fixed-variance"]
#   METRICS: Array(ASCIIString,(8,)) ASCIIString["beats","liars_bonus","correct","MCC","gini","true_rep","liar_rep","gap"]
#   STATISTICS: Array(ASCIIString,(2,)) ASCIIString["mean","stderr"]
#   TRACK: Array(Symbol,(5,)) [:gini,:MCC,:correct,:beats,:liars_bonus]

# %%
using PyPlot;
# Out:
# INFO: Loading help data...

# %%
subplot(221);
contourf(mean_repdelta["fixed-variance"], origin="upper");
title("fixed-variance");
ylabel("reporter");

subplot(222);
colorbar(contourf(mean_repdelta["big-five"], origin="upper"));
title("big-five");

subplot(223);
contourf(mean_repdelta["sztorc"], origin="upper");
title("sztorc");
xlabel("reporting round");
ylabel("reporter");

subplot(224);
colorbar(contourf(mean_repdelta["absolute"], origin="upper"));
title("absolute");
xlabel("reporting round");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f9b2936a350>)

# %%
fig = figure();

subplot(221);
metric = :MCC;
plot(
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["big-five"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["absolute"][metric], 2),
);
grid();
ylabel("Matthews corr. coeff.");
legend(["sztorc", "big-five", "fixed-variance", "absolute"],
       bbox_to_anchor=(-0.15, 1.35),
       loc="upper left",
       ncol=4);

subplot(222);
metric = :correct;
plot(
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["big-five"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["absolute"][metric], 2),
);
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("linear");
ylabel("correct answers");
grid();

subplot(223);
metric = :beats;
plot(
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["big-five"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["absolute"][metric], 2),
);
ax = gca();
ax[:set_xscale]("linear");
xlabel("reporting round");
ylabel("beats");
grid();

subplot(224);
metric = :liars_bonus;
plot(
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["big-five"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["absolute"][metric], 2),
);
xlabel("reporting round");
ylabel("liars' bonus");
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("linear");
grid();

fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f9b28f40d50>)

# %%
fig = figure();
errorbar(timesteps, mean_rep_liars["sztorc"], yerr=std_rep_liars["sztorc"]);
hold("on");
errorbar(timesteps, mean_rep_liars["big-five"], yerr=std_rep_liars["big-five"]);
errorbar(timesteps, mean_rep_liars["fixed-variance"], yerr=std_rep_liars["fixed-variance"]);
errorbar(timesteps, mean_rep_liars["absolute"], yerr=std_rep_liars["absolute"]);
xlabel("time (# reporting rounds)");
ylabel("liars' reputation");
ax = gca();
ax[:set_xscale]("linear");
grid();
legend(["sztorc", "big-five", "fixed-variance", "absolute"],
       loc="center right",
       bbox_to_anchor=(1.4, 0.55),
       ncol=1);
fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f9b28f564d0>)
