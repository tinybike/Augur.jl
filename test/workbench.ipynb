# %%
reload("repl.jl");
# Out:
# Initial token distribution:
# Dict{Symbol,Float64} with 3 entries:
#   :trues    => 0.3706014934712969
#   :liars    => 0.6293985065287031
#   :distorts => 0.0
# figure not defined
# while loading /home/jack/.julia/v0.3/Simulator/test/repl.jl, in expression starting on line 175
# while loading In[1], in expression starting on line 1
#
#  in include at ./boot.jl:245
#  in include_from_node1 at ./loading.jl:128
#  in reload_path at loading.jl:152
#  in reload at loading.jl:85

# %%
xdump(sim)
# Out:
# Simulation
#
#   EVENTS: Int64 40
#   REPORTERS: Int64 80
#   ITERMAX: Int64 25
#   SQRTN: Float64 15.811388300841896
#   TIMESTEPS: Int64 100
#   SCALARS: Float64 0.0
#   SCALARMIN: Float64 0.0
#   SCALARMAX: Float64 1000.0
#   LIAR_THRESHOLD: Float64 0.7
#   VARIANCE_THRESHOLD: Float64 0.9
#   DISTORTER: Bool
#  false
#   DISTORT: Float64 0.0
#   DISTORT_THRESHOLD: Float64 0.1
#   RESPONSES: FloatRange{Float64}
#     start: Float64 2.0
#     step: Float64 1.0
#     len: Float64 3.0
#     divisor: Float64 2.0
#   ALPHA: Float64 0.2
#   REP_BINS: Int64 10
#   REP_RAND: Bool true
#   REP_DIST: Pareto
#
#     α: Float64 3.0
#     β: Float64 1.0
#   BRIDGE: Bool false
#   MARKET_DIST: Pareto
#     α: Float64 3.0
#     β: Float64 1.0
#   PRICE_DIST: Uniform
#     a: Float64 0.0
#     b: Float64 1.0
#   OVERLAP_DIST: Exponential
#
#     β: Float64 1.0
#   RARE: Float64 1.0e-5
#   MONEYBIN: Float64 24.0
#   CORRUPTION: Float64 0.75
#   COLLUDE: Float64 0.3
#   INDISCRIMINATE: Bool true
#   VERBOSE: Bool false
#   CONSPIRACY: Bool false
#   ALLWRONG: Bool false
#   VIRIALMAX: Int64 8
#   SAVE_RAW_DATA: Bool false
#   ALGOS: Array(ASCIIString,(4,))
# ASCIIString["cokurtosis","sztorc","fixed-variance","virial"]
#   METRICS: Array(ASCIIString,(11,)) ASCIIString["beats","liars_bonus","correct","sensitivity","fallout","precision","MCC","gini","true_rep","liar_rep","gap"]
#   STATISTICS: Array(ASCIIString,(2,)) ASCIIString["mean","stderr"]
#   TRACK: Array(Symbol,(8,))
# [:gini,:MCC,:correct,:beats,:sensitivity,:precision,:fallout,:liars_bonus]

# %%
(data[:num_trues], data[:num_liars])
# Out:
# (26,54)

# %%
(println("trues: ", repr(round(tokens[:trues]*100,6)) * "%"),
 println("liars: ", repr(round(tokens[:liars]*100,6)) * "%"));
# Out:
# trues: 37.060149%
# liars: 62.939851%

# %%
vcat(head(initdf), tail(initdf))
# Out:
# 12x4 DataFrame
# | Row | label_sort_by_label | reputation_sort_by_label | label_sort_by_rep |
# |-----|---------------------|--------------------------|-------------------|
# | 1   | "liar"              | 0.00962492               | "liar"            |
# | 2   | "liar"              | 0.0132973                | "liar"            |
# | 3   | "liar"              | 0.0101414                | "true"            |
# | 4   | "liar"              | 0.0106863                | "liar"            |
# | 5   | "liar"              | 0.0144551                | "liar"            |
# | 6   | "liar"              | 0.0171133                | "liar"            |
# | 7   | "true"              | 0.009324                 | "liar"            |
# | 8   | "true"              | 0.00796291               | "true"            |
# | 9   | "true"              | 0.0171679                | "true"            |
# | 10  | "true"              | 0.0116695                | "true"            |
# | 11  | "true"              | 0.0103135                | "liar"            |
# | 12  | "true"              | 0.0117891                | "true"            |
#
# | Row | reputation_sort_by_rep |
# |-----|------------------------|
# | 1   | 0.0075694              |
# | 2   | 0.0075921              |
# | 3   | 0.00766766             |
# | 4   | 0.00771557             |
# | 5   | 0.00774084             |
# | 6   | 0.00774841             |
# | 7   | 0.0212034              |
# | 8   | 0.0251446              |
# | 9   | 0.0261145              |
# | 10  | 0.0341171              |
# | 11  | 0.0468233              |
# | 12  | 0.0507204              |

# %%
vcat(head(df), tail(df));

# %%
using PyPlot;
# Out:
# INFO: Loading help data...

# %%
subplot(221);
contourf(mean_repdelta["fixed-variance"], origin="upper");
title("fixed-variance");
ylabel("reporter");

subplot(222);
colorbar(contourf(mean_repdelta["sztorc"], origin="upper"));
title("sztorc");

subplot(223);
contourf(mean_repdelta["cokurtosis"], origin="upper");
title("cokurtosis");
xlabel("reporting round");
ylabel("reporter");

subplot(224);
colorbar(contourf(mean_repdelta["virial"], origin="upper"));
title("virial");
xlabel("reporting round");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f69f95ca310>)

# %%
fig = figure();

subplot(221);
metric = :MCC;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
grid();
ylabel("Matthews corr. coeff.");
legend(["cokurtosis", "sztorc", "fixed-variance", "virial"],
       bbox_to_anchor=(-0.15, 1.35),
       loc="upper left",
       ncol=4);

subplot(222);
metric = :correct;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
ylabel("correct answers");
grid();

subplot(223);
metric = :beats;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
ax = gca();
ax[:set_xscale]("log");
xlabel("reporting round");
ylabel("beats");
grid();

subplot(224);
metric = :liars_bonus;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
xlabel("reporting round");
ylabel("liars' bonus");
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
grid();

fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f6a01c63b10>)

# %%
fig = figure();
errorbar(timesteps, mean_rep_liars["fixed-variance"], yerr=std_rep_liars["fixed-variance"]);
hold("on");
errorbar(timesteps, mean_rep_liars["sztorc"], yerr=std_rep_liars["sztorc"]);
errorbar(timesteps, mean_rep_liars["cokurtosis"], yerr=std_rep_liars["cokurtosis"]);
errorbar(timesteps, mean_rep_liars["virial"], yerr=std_rep_liars["virial"]);
xlabel("time (# reporting rounds)");
ylabel("reputation");
ax = gca();
ax[:set_xscale]("log");
grid();
legend(["cokurtosis", "sztorc", "fixed-variance", "virial"],
       loc="center right",
       bbox_to_anchor=(1.4, 0.55),
       ncol=1);
fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f69f7fa8050>)
