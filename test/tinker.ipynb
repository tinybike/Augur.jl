# %%
reload("repl.jl");

# %%
(data[:num_trues], data[:num_liars])
# Out:
# (11,39)

# %%
df = DataFrame(honesty=data[:reporters],
               fixed_variance=repdelta["fixed-variance"][:,end,1],
               sztorc=repdelta["sztorc"][:,end,1],
               cokurtosis=repdelta["cokurtosis"][:,end,1],
               virial=repdelta["virial"][:,end,1]);
vcat(head(df), tail(df))
# Out:
# 12x5 DataFrame
# | Row | honesty | fixed_variance | sztorc     | cokurtosis | virial |
# |-----|---------|----------------|------------|------------|--------|
# | 1   | "liar"  | -0.02          | -0.0199998 | -0.02      | -0.02  |
# | 2   | "liar"  | -0.02          | -0.0199997 | -0.02      | -0.02  |
# | 3   | "liar"  | -0.02          | -0.0199997 | -0.02      | -0.02  |
# | 4   | "liar"  | -0.02          | -0.0199997 | -0.02      | -0.02  |
# | 5   | "liar"  | -0.02          | -0.0199998 | -0.02      | -0.02  |
# | 6   | "liar"  | -0.02          | -0.0199995 | -0.02      | -0.02  |
# | 7   | "true"  | 0.0799999      | -0.02      | 0.08       | 0.08   |
# | 8   | "true"  | 0.0799999      | -0.02      | 0.08       | 0.08   |
# | 9   | "true"  | 0.0799999      | -0.02      | 0.08       | 0.08   |
# | 10  | "true"  | 0.0799999      | -0.02      | 0.08       | 0.08   |
# | 11  | "true"  | 0.0799999      | -0.02      | 0.08       | 0.08   |
# ...

# %%
using PyPlot;
# Out:
# INFO: Loading help data...

# %%
subplot(221);
contourf(repdelta["fixed-variance"][:,:,1],origin="upper");
title("fixed-variance");
ylabel("reporter");

subplot(222);
colorbar(contourf(repdelta["sztorc"][:,:,1],origin="upper"));
title("sztorc");

subplot(223);
contourf(repdelta["cokurtosis"][:,:,1],origin="upper");
title("cokurtosis");
xlabel("reporting round");
ylabel("reporter");

subplot(224);
colorbar(contourf(repdelta["virial"][:,:,1],origin="upper"));
title("virial");
xlabel("reporting round");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f94a1f4ced0>)

# %%
fig = figure();

subplot(221);
metric = :MCC;
plot(
    1:sim.TIMESTEPS, track["cokurtosis"][metric],
    1:sim.TIMESTEPS, track["sztorc"][metric],
    1:sim.TIMESTEPS, track["fixed-variance"][metric],
    1:sim.TIMESTEPS, track["virial"][metric],
);
grid();
ylabel("Matthews corr. coeff.");
ax = gca();
ax[:set_xscale]("log");
legend(["cokurtosis", "sztorc", "fixed-variance", "virial"], bbox_to_anchor=(-0.15, 1.35), loc="upper left", ncol=4);

subplot(222);
metric = :correct;
plot(
    1:sim.TIMESTEPS, track["cokurtosis"][metric],
    1:sim.TIMESTEPS, track["sztorc"][metric],
    1:sim.TIMESTEPS, track["fixed-variance"][metric],
    1:sim.TIMESTEPS, track["virial"][metric],
);
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
ylabel("correct answers");
grid();

subplot(223);
metric = :beats;
plot(
    1:sim.TIMESTEPS, track["cokurtosis"][metric],
    1:sim.TIMESTEPS, track["sztorc"][metric],
    1:sim.TIMESTEPS, track["fixed-variance"][metric],
    1:sim.TIMESTEPS, track["virial"][metric],
);
ax = gca();
ax[:set_xscale]("log");
xlabel("reporting round");
ylabel("beats");
grid();

subplot(224);
metric = :liars_bonus;
plot(
    1:sim.TIMESTEPS, track["cokurtosis"][metric],
    1:sim.TIMESTEPS, track["sztorc"][metric],
    1:sim.TIMESTEPS, track["fixed-variance"][metric],
    1:sim.TIMESTEPS, track["virial"][metric],
);
xlabel("reporting round");
ylabel("liars' bonus");
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
grid();

fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f94a0379390>)
