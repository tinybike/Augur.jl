# %%
reload("repl.jl");

# %%
(data[:num_trues], data[:num_liars])
# Out:
# (38,12)

# %%
df = DataFrame(honesty=data[:reporters],
               fixed_variance=repdelta["fixed-variance"][:,end,1],
               sztorc=repdelta["sztorc"][:,end,1],
               cokurtosis=repdelta["cokurtosis"][:,end,1],
               virial=repdelta["virial"][:,end,1]);
vcat(head(df), tail(df))
# Out:
# 12x5 DataFrame
# | Row | honesty | fixed_variance | sztorc     | cokurtosis | virial     |
# |-----|---------|----------------|------------|------------|------------|
# | 1   | "liar"  | -0.02          | -0.02      | -0.02      | -0.02      |
# | 2   | "liar"  | -0.02          | -0.02      | -0.02      | -0.02      |
# | 3   | "liar"  | -0.02          | -0.02      | -0.02      | -0.02      |
# | 4   | "liar"  | -0.02          | -0.02      | -0.02      | -0.02      |
# | 5   | "liar"  | -0.02          | -0.02      | -0.02      | -0.02      |
# | 6   | "liar"  | -0.02          | -0.02      | -0.02      | -0.02      |
# | 7   | "true"  | 0.00702703     | 0.00702703 | 0.00702703 | 0.00702703 |
# | 8   | "true"  | 0.00702703     | 0.00702703 | 0.00702703 | 0.00702703 |
# | 9   | "true"  | 0.00702703     | 0.00702703 | 0.00702703 | 0.00702703 |
# | 10  | "true"  | 0.00702703     | 0.00702703 | 0.00702703 | 0.00702703 |
# | 11  | "true"  | 0.00702703     | 0.00702703 | 0.00702703 | 0.00702703 |
# | 12  | "true"  | -0.02          | -0.02      | -0.02      | -0.02      |

# %%
using PyPlot;
# Out:
# INFO: Loading help data...

# %%
subplot(221);
contourf(squeeze(mean(repdelta["fixed-variance"], 3), 3),origin="upper");
title("fixed-variance");
ylabel("reporter");

subplot(222);
colorbar(contourf(squeeze(mean(repdelta["sztorc"], 3), 3),origin="upper"));
title("sztorc");

subplot(223);
contourf(squeeze(mean(repdelta["cokurtosis"], 3), 3),origin="upper");
title("cokurtosis");
xlabel("reporting round");
ylabel("reporter");

subplot(224);
colorbar(contourf(squeeze(mean(repdelta["virial"], 3), 3),origin="upper"));
title("virial");
xlabel("reporting round");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f169ed5bb50>)

# %%
fig = figure();

subplot(221);
metric = :MCC;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
grid();
ylabel("Matthews corr. coeff.");
legend(["cokurtosis", "sztorc", "fixed-variance", "virial"],
       bbox_to_anchor=(-0.15, 1.35),
       loc="upper left",
       ncol=4);

subplot(222);
metric = :correct;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
ylabel("correct answers");
grid();

subplot(223);
metric = :beats;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
ax = gca();
ax[:set_xscale]("log");
xlabel("reporting round");
ylabel("beats");
grid();

subplot(224);
metric = :liars_bonus;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
xlabel("reporting round");
ylabel("liars' bonus");
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
grid();

fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f169f3d8b90>)

# %%
trajectory
# Out:
# Dict{String,Dict{Symbol,Dict{Symbol,Array{Float64,1}}}} with 4 entries:
#   "virial"         => [:MCC=>[:mean=>[0.9480429447557819,0.9480429447557819,0.9…
#   "cokurtosis"     => [:MCC=>[:mean=>[0.9480429447557819,0.9480429447557819,0.9…
#   "fixed-variance" => [:MCC=>[:mean=>[0.942273737999502,0.9480429447557819,0.94…
#   "sztorc"         => [:MCC=>[:mean=>[0.9532386502802037,0.9480429447557819,0.9…
