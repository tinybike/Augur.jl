# %%
reload("repl.jl");

# %%
(data[:num_trues], data[:num_liars])
# Out:
# (26,54)

# %%
(println("trues: ", repr(round(tokens[:trues]*100,6)) * "%"),
 println("liars: ", repr(round(tokens[:liars]*100,6)) * "%"));
# Out:
# trues: 0.00027%
# liars: 99.99973%

# %%
df = DataFrame(honesty=data[:reporters],
               fixed_variance=repdelta["fixed-variance"][:,end,1],
               sztorc=repdelta["sztorc"][:,end,1],
               cokurtosis=repdelta["cokurtosis"][:,end,1],
               virial=repdelta["virial"][:,end,1]);
vcat(head(df), tail(df))
# Out:
# 12x5 DataFrame
# | Row | honesty | fixed_variance | sztorc      | cokurtosis  | virial      |
# |-----|---------|----------------|-------------|-------------|-------------|
# | 1   | "liar"  | -0.00821976    | -0.0172092  | -0.0245643  | -0.00953262 |
# | 2   | "liar"  | -0.00997651    | -0.035209   | -0.00934088 | -0.0106651  |
# | 3   | "liar"  | -0.0114607     | -0.0100374  | -0.016433   | -0.0109423  |
# | 4   | "liar"  | -0.0159712     | -0.0109819  | -0.00821134 | -0.0195966  |
# | 5   | "liar"  | -0.011208      | -0.0094959  | -0.00846871 | -0.0262951  |
# | 6   | "liar"  | -0.0086608     | -0.0100769  | -0.0194454  | -0.00963765 |
# | 7   | "true"  | 0.0294144      | -0.0132469  | -0.00913698 | -0.0101363  |
# | 8   | "true"  | 0.0181203      | -0.0117835  | -0.00979394 | -0.0108488  |
# | 9   | "true"  | 0.0346865      | -0.00927409 | -0.00975425 | -0.0161097  |
# | 10  | "true"  | 0.0195521      | -0.0101992  | -0.0168283  | -0.0108584  |
# | 11  | "true"  | 0.0227318      | -0.0100235  | -0.0192038  | -0.0114973  |
# | 12  | "true"  | -0.00837717    | -0.0104181  | -0.00934422 | -0.0129818  |

# %%
using PyPlot;

# %%
subplot(221);
contourf(squeeze(mean(repdelta["fixed-variance"], 3), 3),origin="upper");
title("fixed-variance");
ylabel("reporter");

subplot(222);
colorbar(contourf(squeeze(mean(repdelta["sztorc"], 3), 3),origin="upper"));
title("sztorc");

subplot(223);
contourf(squeeze(mean(repdelta["cokurtosis"], 3), 3),origin="upper");
title("cokurtosis");
xlabel("reporting round");
ylabel("reporter");

subplot(224);
colorbar(contourf(squeeze(mean(repdelta["virial"], 3), 3),origin="upper"));
title("virial");
xlabel("reporting round");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f3cd7d6c050>)

# %%
fig = figure();

subplot(221);
metric = :MCC;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
grid();
ylabel("Matthews corr. coeff.");
legend(["cokurtosis", "sztorc", "fixed-variance", "virial"],
       bbox_to_anchor=(-0.15, 1.35),
       loc="upper left",
       ncol=4);

subplot(222);
metric = :correct;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
ylabel("correct answers");
grid();

subplot(223);
metric = :beats;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
ax = gca();
ax[:set_xscale]("log");
xlabel("reporting round");
ylabel("beats");
grid();

subplot(224);
metric = :liars_bonus;
plot(
    1:sim.TIMESTEPS, mean(track["cokurtosis"][metric], 2),
    1:sim.TIMESTEPS, mean(track["sztorc"][metric], 2),
    1:sim.TIMESTEPS, mean(track["fixed-variance"][metric], 2),
    1:sim.TIMESTEPS, mean(track["virial"][metric], 2),
);
xlabel("reporting round");
ylabel("liars' bonus");
ax = gca();
ax[:yaxis][:set_ticks_position]("right");
ax[:set_xscale]("log");
grid();

fig[:canvas][:draw]();
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f3cd8353410>)

# %%
tokens = (Symbol => Float64)[
    :trues => sum(reputation .* (reporters[:reporters] .== "true")),
    :liars => sum(reputation .* (reporters[:reporters] .== "liar")),
    :distorts => sum(reputation .* (reporters[:reporters] .== "distort")),
]
# Out:
# Dict{Symbol,Float64} with 3 entries:
#   :trues    => 2.6951755070672674e-6
#   :liars    => 0.9999973048244929
#   :distorts => 0.0
